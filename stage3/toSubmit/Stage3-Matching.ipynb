# %%
import py_entitymatching as em
import logging

# %%
table_a = em.read_csv_metadata('anime_1.csv', key='ID')
table_b = em.read_csv_metadata('animePlayer.csv', key='ID')
# Out:
# No handlers could be found for logger "py_entitymatching.io.parsers"

# %%
candidate_set = em.read_csv_metadata('candidate_set.csv', ltable=table_a,rtable=table_b)
len(candidate_set)
# Out:
# 81318

# %%
sample = em.sample_table(candidate_set,600)

# %%
sample
# Out:
#          _id  ltable_ID  rtable_ID  \
# 1          1       2429          1
# 285      285       1055         55
# 324      324         34         62
# 390      390       1081         67
# 561      561       1043         77
# 569      569       1171         77
# 708      708       2330         81
# 899      899        887        101
# 1119    1119       3035        125
# 1362    1362       2811        144
# 1382    1382       2419        151
# 1458    1458       2706        167
# 1528    1528        400        182
# 1548    1548       1148        183
# 1585    1585       1321        187
# 1651    1651        920        196
# 2207    2207        977        238
# 2523    2523        995        286
# 2623    2623       1405        292
# 2669    2669        647        302
# 2687    2687        201        303
# 2819    2819       1462        329
# 2868    2868       1117        336
# 2896    2896        900        343
# 3056    3056        955        360
# 3406    3406       1114        406
# 3693    3693        462        425
# 3714    3714        914        427
# 3810    3810       1448        432
# 4090    4090        980        451
# ...      ...        ...        ...
# 76812  76812       1021       9630
# 77511  77511       1079       9696
# 77838  77838       1047       9730
# 78046  78046       1050       9753
# 78080  78080       1735       9753
# 78337  78337        979       9762
# 78344  78344        992       9762
# 78354  78354       1027       9762
# 78558  78558        991       9764
# 78600  78600       1153       9764
# 78652  78652       1900       9769
# 78685  78685       1925       9778
# 78701  78701        903       9780
# 78785  78785       1199       9780
# 78878  78878       1179       9781
# 78917  78917        968       9782
# 79005  79005       2869       9785
# 79132  79132       1030       9797
# 79194  79194       2451       9801
# 79274  79274        784       9823
# 79480  79480       1570       9843
# 79521  79521       2522       9847
# 79896  79896        929       9892
# 80078  80078       1178       9900
# 80193  80193       1225       9902
# 80228  80228        957       9905
# 80795  80795       3092       9950
# 81063  81063       2035       9985
# 81165  81165        936      10009
# 81189  81189        704      10013
#
#                                                               ltable_Title  \
# 1                                                 Tongari Boushi no Memole
# 285                                             Grisaia no Rakuen Specials
# 324                                                 Ghost in the Shell 2.0
# 390                                    Tales of the Abyss Special Fan Disc
# 561                                Mokke Specials (Mokke Special Episodes)
# 569                                             Arslan Senki (TV) Specials
# 708                                                    Cobra The Animation
# 899                                     Megami Kouhosei Special Curriculum
# 1119                                        Fushigi Mahou Fun Fun Pharmacy
# 1362                                   Medarot Damashii (Medabots Spirits)
# 1382                                                        Captain Future
# 1458                                                 Mobile Suit Gundam ZZ
# 1528                                   Bishoujo Senshi Sailor Moon Crystal
# 1548                                                 Kämpfer für die Liebe
# 1585                                                        Bakemonogatari
# 1651                  Ore no Imouto ga Konnani Kawaii Wake ga Nai Specials
# 2207                                              High School DxD Specials
# 2523                                       Shakugan no Shana Movie Special
# 2623                                                        Hanamonogatari
# 2669        3x3 Eyes Seima Densetsu (3x3 Eyes: Legend of the Divine Demon)
# 2687                     Aoki Densetsu Shoot! (Movie) (Blue Legend Shoot!)
# 2819                         Saiunkoku Monogatari (The Story of Saiunkoku)
# 2868                                        Di Gi Charat Christmas Special
# 2896                                     Gekkan Shoujo Nozaki-kun Specials
# 3056                                               Toshokan Sensou Special
# 3406                               Fate/kaleid liner Prisma☆Illya Specials
# 3693                                                        Fairy Tail OVA
# 3714                                                  Kill la Kill Special
# 3810                        Azumanga Daioh (Azumanga Daioh: The Animation)
# 4090                                               Galaxy Angel 3 Specials
# ...                                                                    ...
# 76812                                 Pokemon Diamond &amp; Pearl Specials
# 77511                                                  Terra e... Specials
# 77838                                               Thermae Romae Specials
# 78046                                 Mai-HiME Specials (My-Hime Specials)
# 78080                Fushigi no Umi no Nadia (Nadia: Secret of Blue Water)
# 78337                                                  Bakuman. 3 Specials
# 78344                               Shakugan no Shana III (Final) Specials
# 78354                                      Toaru Majutsu no Index Specials
# 78558                                                   Sabagebu! Specials
# 78600    Umineko no Naku Koro ni Specials (When the Seagulls Cry Specials)
# 78652                                                     Gatchaman Crowds
# 78685                                                    Dragon Ball Super
# 78701                                       Hidamari Sketch x ☆☆☆ Specials
# 78785                                       Aru Tabibito no Nikki Specials
# 78878                                                     Etotama Specials
# 78917                                            Seikai no Monshou Special
# 79005                                                     Massugu ni Ikou.
# 79132                                               Galaxy Angel Z Special
# 79194                         Manga Sarutobi Sasuke (Ninja the Wonder Boy)
# 79274                                                   Dirty Pair Flash 3
# 79480  Densetsu no Yuusha no Densetsu (The Legend of the Legendary Heroes)
# 79521                                                   Shin Koihime†Musou
# 79896                                           Cardcaptor Sakura Specials
# 80078                                                   Teekyuu 4 Specials
# 80193                                                   To Heart 2 Special
# 80228                                                  Black Jack Specials
# 80795                                           Nangoku Shounen Papuwa-kun
# 81063                               Inou-Battle wa Nichijou-kei no Naka de
# 81165                                             Junjou Romantica Special
# 81189    Zettai Karen Children Gentei Kaikin!! OVA Chou Sakidori Special!!
#
#                                            ltable_Genres_Merged  \
# 1                                            FantasyMagicShoujo
# 285                                                 ComedyEcchi
# 324                        ActionMechaPolicePsychologicalSci-Fi
# 390                                           ComedySliceofLife
# 561                              MysterySliceofLifeSupernatural
# 569                                                      Comedy
# 708                                  ActionAdventureSci-FiSpace
# 899                              ActionMechaMilitarySci-FiSpace
# 1119                                                  KidsMagic
# 1362                                      ActionAdventureSci-Fi
# 1382                               ActionAdventureSci-FiShounen
# 1458                 ComedyDramaMechaMilitarySci-FiShounenSpace
# 1528                                   DemonsMagicRomanceShoujo
# 1548                        ActionComedyEcchiShoujoAiSuperPower
# 1585                          MysteryRomanceSupernaturalVampire
# 1651                                    ComedySeinenSliceofLife
# 2207                        ComedyDemonsEcchiHaremRomanceSchool
# 2523                               AdventureComedyFantasyParody
# 2623                                  ComedyMysterySupernatural
# 2669                  ActionAdventureDemonsFantasyHorrorRomance
# 2687                                        ActionShounenSports
# 2819               AdventureComedyDramaFantasyHistoricalRomance
# 2868                                                     Comedy
# 2896                                        ComedyRomanceSchool
# 3056                           ActionComedyDramaMilitaryRomance
# 3406                                         ComedyFantasyMagic
# 3693                             ComedyEcchiFantasyMagicShounen
# 3714                               ActionComedySchoolSuperPower
# 3810                                    ComedySchoolSliceofLife
# 4090                                               ComedySci-Fi
# ...                                                         ...
# 76812                                   ActionComedyFantasyKids
# 77511                                      AdventureDramaSci-Fi
# 77838                                    ComedyHistoricalSeinen
# 78046                                                    Comedy
# 78080                              AdventureComedyRomanceSci-Fi
# 78337                                                    Comedy
# 78344                                              ComedyParody
# 78354                                              ComedyParody
# 78558                                ActionComedyMilitaryShoujo
# 78600                                              ComedyParody
# 78652                                           AdventureSci-Fi
# 78685  ActionAdventureComedyFantasyMartialArtsShounenSuperPower
# 78701                                   ComedySchoolSliceofLife
# 78785                                          AdventureFantasy
# 78878                                       ActionComedyFantasy
# 78917                          ActionMilitaryRomanceSci-FiSpace
# 79005                             ComedyJoseiRomanceSliceofLife
# 79132                                              ComedySci-Fi
# 79194                     AdventureComedyHistoricalSupernatural
# 79274                    ActionAdventureComedyEcchiPoliceSci-Fi
# 79480                        ActionAdventureFantasyMagicShounen
# 79521                              ComedyEcchiFantasyHistorical
# 79896                                                    Comedy
# 80078                                 ComedySchoolShounenSports
# 80193                                        DramaRomanceSchool
# 80228                                                     Drama
# 80795                                    AdventureComedyShounen
# 81063                ComedyRomanceSchoolSliceofLifeSupernatural
# 81165                                    ComedyRomanceShounenAi
# 81189                           ActionComedyShounenSupernatural
#
#       ltable_Episodes                ltable_Year ltable_Type  \
# 1                  50                  1984-1985          TV
# 285                 5                  2015-2015     Special
# 324                 1                  2008-2008       Movie
# 390                 2                  2009-2009     Special
# 561                 2                  2008-2008     Special
# 569           Unknown                2015 -2015      Special
# 708                13                  2010-2010          TV
# 899                 1                  2002-2002         OVA
# 1119               48                  1998-1999          TV
# 1362               39                  2000-2001          TV
# 1382               52                  1978-1979          TV
# 1458               47                  1986-1987          TV
# 1528               26                  2014-2015         ONA
# 1548                2                  2011-2011     Special
# 1585               15                  2009-2010          TV
# 1651                4                  2011-2011     Special
# 2207                6                  2012-2012     Special
# 2523                1                  2007-2007     Special
# 2623                5                  2014-2014          TV
# 2669                3                  1995-1996         OVA
# 2687                1                  1994-1994       Movie
# 2819               39                  2006-2007          TV
# 2868                1                  2000-2000     Special
# 2896                6                  2014-2015     Special
# 3056                1                  2008-2008     Special
# 3406                5                  2013-2014     Special
# 3693                5                  2011-2013         OVA
# 3714                1                  2014-2014     Special
# 3810               26                  2002-2002          TV
# 4090                2                  2003-2003     Special
# ...               ...                        ...         ...
# 76812               2                  2011-2011     Special
# 77511               3  2007 to 2008-2007 to 2008     Special
# 77838               2                  2012-2012     Special
# 78046              27                  2005-2010     Special
# 78080              39                  1990-1991          TV
# 78337               2                  2013-2013     Special
# 78344               2                  2012-2012     Special
# 78354               2                  2009-2009     Special
# 78558               6                  2014-2015     Special
# 78600              26                  2009-2010     Special
# 78652              12                  2013-2013          TV
# 78685         Unknown                2015 -2015           TV
# 78701               2                  2010-2010     Special
# 78785               3                  2006-2006     Special
# 78878               6                  2015-2015     Special
# 78917               1                  2000-2000     Special
# 79005               4                  2003-2003          TV
# 79132               1                  2002-2002     Special
# 79194              24                  1979-1980          TV
# 79274               5                  1995-1996         OVA
# 79480              24                  2010-2010          TV
# 79521              12                  2009-2009          TV
# 79896               3                  1998-1999     Special
# 80078               2                  2015-2015     Special
# 80193               1                  2005-2005     Special
# 80228               4                  2003-2004     Special
# 80795              42                  1992-1993          TV
# 81063              12                  2014-2014          TV
# 81165               1                  2008-2008     Special
# 81189               1                  2010-2010         OVA
#
#                                                                   ltable_ProductionHouse_Merged  \
# 1                                                                                 ToeiAnimation
# 285                                                                            Nonefoundaddsome
# 324                                                                               ProductionI.G
# 390                                                                                     Sunrise
# 561                                                                            MadhouseKodansha
# 569                                                                          SANZIGENLIDENFILMS
# 708                                                                                    MagicBus
# 899                                                                                BandaiVisual
# 1119                                                                              ToeiAnimation
# 1362                                                            ProductionI.GADVFilmsNASNelvana
# 1382                                                                              ToeiAnimation
# 1458                                                                                    Sunrise
# 1528                                              ToeiAnimationStarchildRecordsVizMediaKodansha
# 1548                                           J.C.StaffNomadLantisDAXProductionSentaiFilmworks
# 1585                                                       AniplexShaftKodanshaAniplexofAmerica
# 1651                                                            AniplexAICBuildAniplexofAmerica
# 2207                                                      GencoFUNimationEntertainmentLantisTNK
# 2523                                                                                  J.C.Staff
# 2623                                                       AniplexShaftKodanshaAniplexofAmerica
# 2669                                                            BandaiVisualKodanshaStudioJunio
# 2687                                                                           Nonefoundaddsome
# 2819                                               MadhouseFUNimationEntertainmentNHKSogoVision
# 2868                                                                 MadhouseTBSSentaiFilmworks
# 2896                                                                       DogaKoboMediaFactory
# 3056                                                                              ProductionI.G
# 3406                                                                                 SilverLink
# 3693                                                                       SatelightA-1Pictures
# 3714                                               AniplexKadokawaShotenAniplexofAmericaTrigger
# 3810   J.C.StaffGencoADVFilmsLantisImagicaAzumangaDaiohProductionCommitteeTVTokyoMusicCosmicRay
# 4090                                                                BroccoliBandaiEntertainment
# ...                                                                                         ...
# 76812                                                                     OrientalLightandMagic
# 77511                                                                      MinamiMachiBugyousho
# 77838                                                                                       DLE
# 78046                                                                                   Sunrise
# 78080                                                GainaxADVFilmsNHKSogoVisionSentaiFilmworks
# 78337                                                                                 J.C.Staff
# 78344                                                          J.C.StaffFUNimationEntertainment
# 78354                                                                                 J.C.Staff
# 78558                                                                         LantisPierrotPlus
# 78600                                                                   StudioDeenFrontierWorks
# 78652     VAPTatsunokoProductionsDAXProductionSentaiFilmworksNipponTelevisionNetworkCorporation
# 78685                                                      ToeiAnimationYomikoAdvertisingFujiTV
# 78701                                                                               ShaftLantis
# 78785                                                                                     Robot
# 78878                                                                   ShirogumiEncourageFilms
# 78917                                                           SunriseBandaiVisualWOWOWBeSTACK
# 79005                                                                             YumetaCompany
# 79132                                                               BroccoliBandaiEntertainment
# 79194                                                                          KnackProductions
# 79274                                                               SunriseVAPADVFilmsRightStuf
# 79480                        FUNimationEntertainmentLantisMediaFactoryZexcsKadokawaContentsGate
# 79521                                             MarvelousEntertainmentDogaKoboSentaiFilmworks
# 79896                                                                            NHKEnterprises
# 80078                                            DAXProductionEarthStarEntertainmentMillepensee
# 80193                                                                     OrientalLightandMagic
# 80228                                                                         TezukaProductions
# 80795                                                                    NipponAnimationTVAsahi
# 81063                                            TVTokyoHalfH.PStudioTriggerDIVEIIEntertainment
# 81165                                                                                StudioDeen
# 81189                                                                                 SynergySP
#
#                                                       rtable_Title  \
# 1                                  Hagane no Renkinjutsushi (2009)
# 285                                            The Eden of Grisaia
# 324    Ghost in the Shell: Stand Alone Complex - Individual Eleven
# 390                          Hajime no Ippo: The Fighting! Special
# 561                             Monthly Girls' Nozaki-kun Specials
# 569                             Monthly Girls' Nozaki-kun Specials
# 708                           Broken Blade: The Path of Separation
# 899                                   Mayoi Neko Overrun! Specials
# 1119                                       Fushigi na Koala Blinky
# 1362                                                      Medabots
# 1382                       Captain Future: Kareinaru Taiyokei Race
# 1458                        Mobile Suit Gundam AGE: Memory of Eden
# 1528          Pocket Monsters Crystal: Raikou Ikazuchi no Densetsu
# 1548                                         Kampfer fur die Liebe
# 1585                                  Ginga Tetsudou Monogatari II
# 1651                        Hyakka Ryouran: Samurai Girls Specials
# 2207                            Hagure Yuusha no Estetica Specials
# 2523                                 Amaenaideyo!! Katsu!! Special
# 2623             Licca-chan Fushigi na Fushigi na Yunia Monogatari
# 2669                   Legend of the Galactic Heroes: Golden Wings
# 2687                        Ginga Eiyuu Densetsu: Ougon no Tsubasa
# 2819                     Wellber no Monogatari: Sisters of Wellber
# 2868                                              Di Gi Charat Nyo
# 2896                                         Tokyo Ravens Specials
# 3056                  All Purpose Cultural Cat Nuku Nuku Special 1
# 3406                           Ikkitousen: Xtreme Xecutor Specials
# 3693                                 Fairy Musketeers Akazukin OVA
# 3714        Koi suru Tenshi Angelique ~Kagayaki no Ashita~ Special
# 3810                          Choujigen Game Neptune The Animation
# 4090                                      Tenchi in Tokyo Specials
# ...                                                            ...
# 76812                          Kita e ~Diamond Dust Drops~ Special
# 77511                                 Valkyria Chronicles Specials
# 77838                               Da Capo Second Season Specials
# 78046                     Nadia: Secret of the Blue Water Specials
# 78080                     Nadia: Secret of the Blue Water Specials
# 78337                           Princess Resurrection OVA Specials
# 78344                           Princess Resurrection OVA Specials
# 78354                           Princess Resurrection OVA Specials
# 78558                                   Genshiken Nidaime Specials
# 78600                                   Genshiken Nidaime Specials
# 78652                                Kagaku Ninja-Tai Gatchaman II
# 78685                           Dragon Ball: Goku's Traffic Safety
# 78701                        Machine-Doll wa Kizutsukanai Specials
# 78785                        Machine-Doll wa Kizutsukanai Specials
# 78878                            Unbreakable Machine-Doll Specials
# 78917                        Kikou Shoujo wa Kizutsukanai Specials
# 79005                                       Massugu ni Ikou (2004)
# 79132                       Tokimeki Memorial ~Only Love~ Specials
# 79194                          Spirit of Wonder: Miss China's Ring
# 79274                                             Dirty Pair Flash
# 79480                                   Densetsu no Yuusha Da Garn
# 79521                                            Koihime Musou OVA
# 79896                            Bokura wa Minna Kawaisou Specials
# 80078                               Aru Tabibito no Nikki Specials
# 80193                              Diary of Tortov Roddle Specials
# 80228                      Fate/Kaleid Liner Prisma Illya Specials
# 80795                         Kindaichi Shounen no Jikenbo Returns
# 81063               Harukanaru Toki no Naka de 3: Kurenai no Tsuki
# 81165                                      Jewelpet Tinkle Special
# 81189                           Pokemon: Diamond and Pearl Special
#
#                                                              rtable_Genres_Merged  \
# 1      ActionAdventureAnimalAbuseBasedonaMangaDramaFantasyMilitaryMysteryViolence
# 285                           BasedonaVisualNovelComedyDramaMilitarySexualContent
# 324                                        CyberpunkCyborgsFuturisticHackingSciFi
# 390                                                        BoxingHandtoHandCombat
# 561                                                 BasedonaMangaComedySchoolLife
# 569                                                 BasedonaMangaComedySchoolLife
# 708                                            ActionFantasyMagicMechaMilitaryWar
# 899                                                                           NaN
# 1119                                 AnimalProtagonistsFamilyFriendlyOriginalWork
# 1362                                               ActionRobotsShounenTournaments
# 1382                                                     AdventureOuterSpaceSciFi
# 1458                                                                          NaN
# 1528                                                  ActionFamilyFriendlyShounen
# 1548                   ActionBasedonaLightNovelComedyEcchiGenderBenderMagicalGirl
# 1585                                                                          NaN
# 1651                                                        EcchiNudityPantyShots
# 2207                                          BasedonaLightNovelComedyDemonsEcchi
# 2523                                     BasedonaMangaComedyEcchiNudityPantyShots
# 2623                                                                          NaN
# 2669                                       BasedonaNovelOuterSpaceSciFiSpaceOpera
# 2687                                       BasedonaNovelOuterSpaceSciFiSpaceOpera
# 2819                                AdventureFantasyMedievalOriginalWorkPolitical
# 2868                                                                          NaN
# 2896                                                                          NaN
# 3056                                                                BasedonaManga
# 3406                                            ComedyEcchiHandtoHandCombatNudity
# 3693                                                                ActionFantasy
# 3714                                        BasedonanOtomeGameBasedonaVisualNovel
# 3810                                         ActionBasedonaVideoGameFantasySeinen
# 4090                                                                          NaN
# ...                                                                           ...
# 76812                                                                         NaN
# 77511                                                                         NaN
# 77838                                BasedonanErogeBasedonaVisualNovelComedyOmake
# 78046                                                                         NaN
# 78080                                                                         NaN
# 78337                                                                         NaN
# 78344                                                                         NaN
# 78354                                                                         NaN
# 78558                                                          ComedyOtakuCulture
# 78600                                                          ComedyOtakuCulture
# 78652                                                                       SciFi
# 78685                                                                 Educational
# 78701                                                                         NaN
# 78785                                                                         NaN
# 78878                                                                         NaN
# 78917                                                                         NaN
# 79005                                         AnimalProtagonistsComedySliceofLife
# 79132                                                                         NaN
# 79194                                                                     Science
# 79274                                                           ActionComedySciFi
# 79480                                       ActionCombiningMechaMechaSciFiShounen
# 79521                                                       ComedyEcchiSchoolLife
# 79896                                                         BasedonaMangaComedy
# 80078                                        AbstractAdventureFantasyOriginalWork
# 80193                                        AbstractAdventureFantasyOriginalWork
# 80228                                                          FantasyMagicalGirl
# 80795                                                        BasedonaMangaMystery
# 81063                                                  FantasyReverseHaremRomance
# 81165                                                                         NaN
# 81189                                                FamilyFriendlyFantasyShounen
#
#       rtable_Episodes  rtable_Year  rtable_Type rtable_ProductionHouse_Merged
# 1                  64  2009 - 2010           TV                         Bones
# 285                10         2015           TV                         8-Bit
# 324                 1         2006        Movie                 ProductionI.G
# 390                 1         2003  DVD Special                      MADHOUSE
# 561                 6  2014 - 2015  DVD Special                      Dogakobo
# 569                 6  2014 - 2015  DVD Special                      Dogakobo
# 708                 1         2010        Movie                 ProductionI.G
# 899                 6         2010  DVD Special                           AIC
# 1119               26         1984           TV               NipponAnimation
# 1362               52  1999 - 2000           TV                      BEETRAIN
# 1382                1         1978        Movie                 ToeiAnimation
# 1458                1         2013          OVA                       Sunrise
# 1528                1         2001   TV Special                           OLM
# 1548                2         2011        Other                         Nomad
# 1585               26  2006 - 2007           TV                        Planet
# 1651                6  2010 - 2011  DVD Special                          ARMS
# 2207                6  2012 - 2013  DVD Special                          ARMS
# 2523                1         2006  DVD Special                    StudioDeen
# 2623                2         1990          OVA                       Asiadou
# 2669                1         1992        Movie                           NaN
# 2687                1         1992        Movie                           NaN
# 2819               13         2007           TV                  TransArtsCo.
# 2868               52  2003 - 2004           TV                      MADHOUSE
# 2896                3  2013 - 2014          Web                           NaN
# 3056                1         2003  DVD Special               AshiProductions
# 3406                6         2010  DVD Special                           NaN
# 3693                1         2005          OVA                      MADHOUSE
# 3714                1         2007  DVD Special                     Satelight
# 3810               12         2013           TV               DavidProduction
# 4090                6         1997        Other                           AIC
# ...               ...          ...          ...                           ...
# 76812               1         2004  DVD Special                    StudioDeen
# 77511               9  2009 - 2010  DVD Special                   A-1Pictures
# 77838               7         2006  DVD Special                          Feel
# 78046              10         2003  DVD Special                        Gainax
# 78080              10         2003  DVD Special                        Gainax
# 78337               3  2010 - 2011  DVD Special                 TatsunokoPro.
# 78344               3  2010 - 2011  DVD Special                 TatsunokoPro.
# 78354               3  2010 - 2011  DVD Special                 TatsunokoPro.
# 78558               4         2013  DVD Special                 ProductionI.G
# 78600               4         2013  DVD Special                 ProductionI.G
# 78652              52  1978 - 1979           TV                 TatsunokoPro.
# 78685               1         1988   TV Special                 ToeiAnimation
# 78701               6  2013 - 2014  DVD Special                        Lerche
# 78785               6  2013 - 2014  DVD Special                        Lerche
# 78878               6  2013 - 2014  DVD Special                        Lerche
# 78917               6  2013 - 2014  DVD Special                        Lerche
# 79005               5         2004          OVA                        Yumeta
# 79132               2         2007  DVD Special                   AICA.S.T.A.
# 79194               1         1992        Movie                       Asiadou
# 79274              16  1994 - 1996          OVA                       Sunrise
# 79480              46  1992 - 1993           TV                       Sunrise
# 79521               1         2009          OVA                      Dogakobo
# 79896              14  2014 - 2015  DVD Special                   Brains-Base
# 80078               3         2006  DVD Special                         Robot
# 80193               3         2006  DVD Special                         Robot
# 80228               5  2013 - 2014  DVD Special                    SILVERLINK
# 80795              25         2014           TV                 ToeiAnimation
# 81063               1         2007   TV Special                        Yumeta
# 81165               1         2013  DVD Special                   StudioComet
# 81189               1         2011   TV Special                           OLM
#
# [600 rows x 15 columns]

# %%
em.to_csv_metadata(sample,'samples.csv')
# Out:
# True

# %%
#gold = em.label_table(sample,'gold')

# %%
#cols = ['ltable_Title', 'ltable_Genres', 'ltable_Type', 'ltable_ProductionHouse', 'ltable_Year',
#       'rtable_Title', 'rtable_Genres', 'rtable_Type', 'rtable_ProductionHouse', 'rtable_Year']

#for col in cols:
#    gold[col] = gold[col].astype(unicode)

# %%
#gold.head()

# %%
#em.to_csv_metadata(gold, 'transform_genres/gold.csv',encoding='utf-8')

# %%
gold = em.read_csv_metadata('gold_manually_marked.csv',ltable=table_a,rtable=table_b)

# %%
gold.head()
# Out:
#      _id  ltable_ID  rtable_ID  \
# 0  21622          3         17
# 1  25500          5       5343
# 2  21258          6         46
# 3  35823         11       7219
# 4  28070         13       6008
#
#                                                   ltable_Title  \
# 0                                Suzumiya Haruhi no Shoushitsu
# 1              Howl no Ugoku Shiro (Howl&#039;s Moving Castle)
# 2                                           Hotarubi no Mori e
# 3  Kaguya-hime no Monogatari (The Tale of the Princess Kaguya)
# 4                             Love Live! The School Idol Movie
#
#                            ltable_Genres_Merged ltable_Episodes ltable_Year  \
# 0  ComedyMysteryRomanceSchoolSci-FiSupernatural               1   2010-2010
# 1                  AdventureDramaFantasyRomance               1   2004-2004
# 2                DramaRomanceShoujoSupernatural               1   2011-2011
# 3                             FantasyHistorical               1   2013-2013
# 4                        MusicSchoolSliceofLife               1   2015-2015
#
#   ltable_Type                               ltable_ProductionHouse_Merged  \
# 0       Movie  KyotoAnimationKadokawaShotenBandaiEntertainmentAnimationDo
# 1       Movie           StudioGhiblid-rightsTokumaShotenWaltDisneyStudios
# 2       Movie                                           AniplexBrainsBase
# 3       Movie                                           StudioGhibliGKids
# 4       Movie                                               SunriseLantis
#
#                                                                        rtable_Title  \
# 0                                                     Suzumiya Haruhi no Shoushitsu
# 1                                                              Howl's Moving Castle
# 2                                                                Hotarubi no Mori e
# 3  One Piece: The Desert Princess and the Pirates - Adventures in Alabasta Prologue
# 4                                       Gakuen Mokushiroku: High School of the Dead
#
#                                                                            rtable_Genres_Merged  \
# 0                                                             DramaPsychologicalSciFiTimeTravel
# 1                                              AdventureBasedonaNovelFamilyFriendlyFantasyMagic
# 2                            BasedonaMangaComingofAgeJapaneseMythologyRomanceShoujoSupernatural
# 3                                                                                       Pirates
# 4  ActionBasedonaMangaEcchiExplicitViolenceHorrorPandemicPantyShotsPhysicalAbuseSurvivalZombies
#
#   rtable_Episodes rtable_Year rtable_Type rtable_ProductionHouse_Merged  gold
# 0               1        2010       Movie                KyotoAnimation     1
# 1               1        2004       Movie                  StudioGhibli     1
# 2               1        2011       Movie                   Brains-Base     1
# 3               1        2007         OVA                 ToeiAnimation     0
# 4              12        2010          TV                      MADHOUSE     0

# %%
setIJ = em.split_train_test(gold, train_proportion=0.5)

# %%
I = setIJ['train']
J = setIJ['test']
(len(I), len(J))
# Out:
# (300, 300)

# %%
I.head()
# Out:
#        _id  ltable_ID  rtable_ID                             ltable_Title  \
# 128  26222        871       5534  Mahou Tsukai Tai! vs. Shamanic Princess
# 431   9001       2610       1619      Kinnikuman II Sei (Ultimate Muscle)
# 536  47085       3019        955                          Sister Princess
# 81   22403        421       4601              Ninja Slayer From Animation
# 77   39690        413        988                                 Upotte!!
#
#                            ltable_Genres_Merged ltable_Episodes ltable_Year  \
# 128                          ComedyFantasyMagic               1   1998-1998
# 431  ActionComedyMartialArtsSci-FiShounenSports              51   2002-2002
# 536          ComedyDramaHaremRomanceSliceofLife              26   2001-2001
# 81                                       Action              26   2015-2015
# 77                           ActionComedySeinen              10   2012-2012
#
#     ltable_Type                             ltable_ProductionHouse_Merged  \
# 128         OVA                                      BandaiVisualNYAVPost
# 431          TV  TVTokyoToeiAnimation4KidsEntertainmentYomiuriAdvertising
# 536          TV           StarchildRecordsADVFilmsZexcsTVTokyoMusicGANSIS
# 81          ONA     StarchildRecordsFUNimationEntertainmentTriggerGrooove
# 77          ONA           XebecDAXProductionNipponColumbiaSentaiFilmworks
#
#                                                     rtable_Title  \
# 128                                    6HP - Six Hearts Princess
# 431  Kinnikuman: Kessen!! Shichinin no Choujin Tai Uchuu Nobushi
# 536                                              Sister Princess
# 81                             Collection of Key Animation Films
# 77                                                      Upotte!!
#
#                                   rtable_Genres_Merged rtable_Episodes  \
# 128                                                NaN             TV
# 431                                                NaN               1
# 536                        ComedyDramaHaremSliceofLife              26
# 81            JapanAnimatorsExhibitionMechaSciFiShorts               1
# 77   ActionBasedonaMangaComedyEcchiGunfightsSchoolLife              10
#
#     rtable_Year rtable_Type rtable_ProductionHouse_Merged  gold
# 128        2016          TV                      Poncotan     0
# 431        1984  TV Special                 ToeiAnimation     0
# 536        2001          TV                         Zexcs     1
# 81         2014         Web                   StudioKhara     0
# 77         2012         Web                         XEBEC     1

# %%
em.to_csv_metadata(I,'setI.csv')
# Out:
# True

# %%
J.head()
# Out:
#        _id  ltable_ID  rtable_ID                            ltable_Title  \
# 303   5010       1226        824                    Comic Party Specials
# 427    675       2537        109  Senkou no Night Raid (Night Raid 1931)
# 80   39948        420       3023                          Monster Strike
# 114  29137        563       6166                Tenchi Muyou! Ryo-Ohki 3
# 310  26818       1238       5679      Itsuka Tenma no Kuro Usagi Special
#
#                     ltable_Genres_Merged ltable_Episodes  ltable_Year  \
# 303                          ComedyDrama               4    2003-2003
# 427   ActionHistoricalMilitarySuperPower              13    2010-2010
# 80                     ActionFantasyGame         Unknown  2015 -2015
# 114  ActionComedyHaremSci-FiShounenSpace               6    2003-2005
# 310                          ComedyEcchi               1    2012-2012
#
#     ltable_Type             ltable_ProductionHouse_Merged  \
# 303     Special                  OrientalLightandMagicKSS
# 427          TV  TVTokyoAniplexA-1PicturesSentaiFilmworks
# 80          ONA            StudioHibariUltraSuperPictures
# 114         OVA                VAPFUNimationEntertainment
# 310     Special                                     Zexcs
#
#                                      rtable_Title  \
# 303         Fight Ippatsu! Juuden-Chan!! Specials
# 427  Senkou no Night Raid: Demon of the Opium Den
# 80                                 Monster Strike
# 114   Tenchi Muyo! Ryo Ohki: Final Confrontations
# 310                         Mister Ajikko Special
#
#                  rtable_Genres_Merged rtable_Episodes  rtable_Year  \
# 303               ComedySexualContent               6  2009 - 2010
# 427                               NaN               1         2010
# 80   BasedonaVideoGameFantasyMonsters              2+     2015 - ?
# 114                               NaN               1         2005
# 310                               NaN               1         1989
#
#      rtable_Type rtable_ProductionHouse_Merged  gold
# 303  DVD Special                           NaN     0
# 427  DVD Special                   A-1Pictures     1
# 80           Web                  StudioHibari     1
# 114          OVA                           NaN     1
# 310   TV Special                       Sunrise     0

# %%
em.to_csv_metadata(J,'setJ.csv')
# Out:
# True

# %%
dt = em.DTMatcher(name='DecisionTree', random_state=0)
rf = em.RFMatcher(name='RandomForest', random_state=0)
svm = em.SVMMatcher(name='SVM')
nb = em.NBMatcher(name='NaiveBayes')
lg = em.LogRegMatcher(name='LogisticRegression')
ln = em.LinRegMatcher(name='LinearRegression')

# %%
# Names of the matchers
(dt.name, rf.name,svm.name,nb.name, lg.name, ln.name)
# Out:
# ('DecisionTree',
#  'RandomForest',
#  'SVM',
#  'NaiveBayes',
#  'LogisticRegression',
#  'LinearRegression')

# %%
feature_table = em.get_features_for_matching(table_a, table_b)
feature_table
# Out:
#                                                      feature_name  \
# 0                                                       ID_ID_exm
# 1                                                       ID_ID_anm
# 2                                                  ID_ID_lev_dist
# 3                                                   ID_ID_lev_sim
# 4                                     Title_Title_jac_qgm_3_qgm_3
# 5                                 Title_Title_cos_dlm_dc0_dlm_dc0
# 6                                 Title_Title_jac_dlm_dc0_dlm_dc0
# 7                                                 Title_Title_mel
# 8                                            Title_Title_lev_dist
# 9                                             Title_Title_lev_sim
# 10                                                Title_Title_nmw
# 11                                                 Title_Title_sw
# 12                              Episodes_Episodes_jac_qgm_3_qgm_3
# 13                          Episodes_Episodes_cos_dlm_dc0_dlm_dc0
# 14                          Episodes_Episodes_jac_dlm_dc0_dlm_dc0
# 15                                          Episodes_Episodes_mel
# 16                                     Episodes_Episodes_lev_dist
# 17                                      Episodes_Episodes_lev_sim
# 18                                          Episodes_Episodes_nmw
# 19                                           Episodes_Episodes_sw
# 20                                      Year_Year_jac_qgm_3_qgm_3
# 21                                  Year_Year_cos_dlm_dc0_dlm_dc0
# 22                                  Year_Year_jac_dlm_dc0_dlm_dc0
# 23                                                  Year_Year_mel
# 24                                             Year_Year_lev_dist
# 25                                              Year_Year_lev_sim
# 26                                                  Year_Year_nmw
# 27                                                   Year_Year_sw
# 28         ProductionHouse_Merged_ProductionHouse_Merged_lev_dist
# 29          ProductionHouse_Merged_ProductionHouse_Merged_lev_sim
# 30              ProductionHouse_Merged_ProductionHouse_Merged_jar
# 31              ProductionHouse_Merged_ProductionHouse_Merged_jwn
# 32              ProductionHouse_Merged_ProductionHouse_Merged_exm
# 33  ProductionHouse_Merged_ProductionHouse_Merged_jac_qgm_3_qgm_3
# 34                           Genres_Merged_Genres_Merged_lev_dist
# 35                            Genres_Merged_Genres_Merged_lev_sim
# 36                                Genres_Merged_Genres_Merged_jar
# 37                                Genres_Merged_Genres_Merged_jwn
# 38                                Genres_Merged_Genres_Merged_exm
# 39                    Genres_Merged_Genres_Merged_jac_qgm_3_qgm_3
#
#             left_attribute         right_attribute left_attr_tokenizer  \
# 0                       ID                      ID                None
# 1                       ID                      ID                None
# 2                       ID                      ID                None
# 3                       ID                      ID                None
# 4                    Title                   Title               qgm_3
# 5                    Title                   Title             dlm_dc0
# 6                    Title                   Title             dlm_dc0
# 7                    Title                   Title                None
# 8                    Title                   Title                None
# 9                    Title                   Title                None
# 10                   Title                   Title                None
# 11                   Title                   Title                None
# 12                Episodes                Episodes               qgm_3
# 13                Episodes                Episodes             dlm_dc0
# 14                Episodes                Episodes             dlm_dc0
# 15                Episodes                Episodes                None
# 16                Episodes                Episodes                None
# 17                Episodes                Episodes                None
# 18                Episodes                Episodes                None
# 19                Episodes                Episodes                None
# 20                    Year                    Year               qgm_3
# 21                    Year                    Year             dlm_dc0
# 22                    Year                    Year             dlm_dc0
# 23                    Year                    Year                None
# 24                    Year                    Year                None
# 25                    Year                    Year                None
# 26                    Year                    Year                None
# 27                    Year                    Year                None
# 28  ProductionHouse_Merged  ProductionHouse_Merged                None
# 29  ProductionHouse_Merged  ProductionHouse_Merged                None
# 30  ProductionHouse_Merged  ProductionHouse_Merged                None
# 31  ProductionHouse_Merged  ProductionHouse_Merged                None
# 32  ProductionHouse_Merged  ProductionHouse_Merged                None
# 33  ProductionHouse_Merged  ProductionHouse_Merged               qgm_3
# 34           Genres_Merged           Genres_Merged                None
# 35           Genres_Merged           Genres_Merged                None
# 36           Genres_Merged           Genres_Merged                None
# 37           Genres_Merged           Genres_Merged                None
# 38           Genres_Merged           Genres_Merged                None
# 39           Genres_Merged           Genres_Merged               qgm_3
#
#    right_attr_tokenizer       simfunction  \
# 0                  None       exact_match
# 1                  None          abs_norm
# 2                  None          lev_dist
# 3                  None           lev_sim
# 4                 qgm_3           jaccard
# 5               dlm_dc0            cosine
# 6               dlm_dc0           jaccard
# 7                  None       monge_elkan
# 8                  None          lev_dist
# 9                  None           lev_sim
# 10                 None  needleman_wunsch
# 11                 None    smith_waterman
# 12                qgm_3           jaccard
# 13              dlm_dc0            cosine
# 14              dlm_dc0           jaccard
# 15                 None       monge_elkan
# 16                 None          lev_dist
# 17                 None           lev_sim
# 18                 None  needleman_wunsch
# 19                 None    smith_waterman
# 20                qgm_3           jaccard
# 21              dlm_dc0            cosine
# 22              dlm_dc0           jaccard
# 23                 None       monge_elkan
# 24                 None          lev_dist
# 25                 None           lev_sim
# 26                 None  needleman_wunsch
# 27                 None    smith_waterman
# 28                 None          lev_dist
# 29                 None           lev_sim
# 30                 None              jaro
# 31                 None      jaro_winkler
# 32                 None       exact_match
# 33                qgm_3           jaccard
# 34                 None          lev_dist
# 35                 None           lev_sim
# 36                 None              jaro
# 37                 None      jaro_winkler
# 38                 None       exact_match
# 39                qgm_3           jaccard
#
#                                                                                    function  \
# 0                                                       <function ID_ID_exm at 0x10fccb398>
# 1                                                       <function ID_ID_anm at 0x10fccb140>
# 2                                                  <function ID_ID_lev_dist at 0x10fccb2a8>
# 3                                                   <function ID_ID_lev_sim at 0x1106090c8>
# 4                                     <function Title_Title_jac_qgm_3_qgm_3 at 0x110609050>
# 5                                 <function Title_Title_cos_dlm_dc0_dlm_dc0 at 0x110609de8>
# 6                                 <function Title_Title_jac_dlm_dc0_dlm_dc0 at 0x110609b90>
# 7                                                 <function Title_Title_mel at 0x110609e60>
# 8                                            <function Title_Title_lev_dist at 0x110609ed8>
# 9                                             <function Title_Title_lev_sim at 0x110609d70>
# 10                                                <function Title_Title_nmw at 0x10f0cb050>
# 11                                                 <function Title_Title_sw at 0x10f0cb0c8>
# 12                              <function Episodes_Episodes_jac_qgm_3_qgm_3 at 0x10f0cb140>
# 13                          <function Episodes_Episodes_cos_dlm_dc0_dlm_dc0 at 0x10f0cb1b8>
# 14                          <function Episodes_Episodes_jac_dlm_dc0_dlm_dc0 at 0x10f0cb230>
# 15                                          <function Episodes_Episodes_mel at 0x10f0cb2a8>
# 16                                     <function Episodes_Episodes_lev_dist at 0x10f0cb320>
# 17                                      <function Episodes_Episodes_lev_sim at 0x10f0cb398>
# 18                                          <function Episodes_Episodes_nmw at 0x10f0cb410>
# 19                                           <function Episodes_Episodes_sw at 0x10f0cb488>
# 20                                      <function Year_Year_jac_qgm_3_qgm_3 at 0x10f0cb500>
# 21                                  <function Year_Year_cos_dlm_dc0_dlm_dc0 at 0x10f0cb578>
# 22                                  <function Year_Year_jac_dlm_dc0_dlm_dc0 at 0x10f0cb5f0>
# 23                                                  <function Year_Year_mel at 0x10f0cb668>
# 24                                             <function Year_Year_lev_dist at 0x10f0cb6e0>
# 25                                              <function Year_Year_lev_sim at 0x10f0cb758>
# 26                                                  <function Year_Year_nmw at 0x10f0cb7d0>
# 27                                                   <function Year_Year_sw at 0x10f0cb848>
# 28         <function ProductionHouse_Merged_ProductionHouse_Merged_lev_dist at 0x10f0cb8c0>
# 29          <function ProductionHouse_Merged_ProductionHouse_Merged_lev_sim at 0x10f0cb938>
# 30              <function ProductionHouse_Merged_ProductionHouse_Merged_jar at 0x10f0cb9b0>
# 31              <function ProductionHouse_Merged_ProductionHouse_Merged_jwn at 0x10f0cba28>
# 32              <function ProductionHouse_Merged_ProductionHouse_Merged_exm at 0x10f0cbaa0>
# 33  <function ProductionHouse_Merged_ProductionHouse_Merged_jac_qgm_3_qgm_3 at 0x10f0cbb18>
# 34                           <function Genres_Merged_Genres_Merged_lev_dist at 0x10f0cbb90>
# 35                            <function Genres_Merged_Genres_Merged_lev_sim at 0x10f0cbc08>
# 36                                <function Genres_Merged_Genres_Merged_jar at 0x10f0cbc80>
# 37                                <function Genres_Merged_Genres_Merged_jwn at 0x10f0cbcf8>
# 38                                <function Genres_Merged_Genres_Merged_exm at 0x10f0cbd70>
# 39                    <function Genres_Merged_Genres_Merged_jac_qgm_3_qgm_3 at 0x10f0cbde8>
#
#                                                                                         function_source  \
# 0   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 1   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 2   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 3   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 4   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 5   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 6   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 7   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 8   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 9   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 10  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 11  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 12  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 13  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 14  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 15  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 16  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 17  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 18  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 19  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 20  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 21  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 22  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 23  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 24  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 25  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 26  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 27  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 28  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 29  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 30  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 31  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 32  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 33  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 34  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 35  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 36  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 37  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 38  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 39  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
#
#    is_auto_generated
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True
# 20              True
# 21              True
# 22              True
# 23              True
# 24              True
# 25              True
# 26              True
# 27              True
# 28              True
# 29              True
# 30              True
# 31              True
# 32              True
# 33              True
# 34              True
# 35              True
# 36              True
# 37              True
# 38              True
# 39              True

# %%
em._match_s
# Out:
# {'abs_norm': <function py_entitymatching.feature.simfunctions.abs_norm>,
#  'affine': <function py_entitymatching.feature.simfunctions.affine>,
#  'cosine': <function py_entitymatching.feature.simfunctions.cosine>,
#  'dice': <function py_entitymatching.feature.simfunctions.dice>,
#  'exact_match': <function py_entitymatching.feature.simfunctions.exact_match>,
#  'hamming_dist': <function py_entitymatching.feature.simfunctions.hamming_dist>,
#  'hamming_sim': <function py_entitymatching.feature.simfunctions.hamming_sim>,
#  'jaccard': <function py_entitymatching.feature.simfunctions.jaccard>,
#  'jaro': <function py_entitymatching.feature.simfunctions.jaro>,
#  'jaro_winkler': <function py_entitymatching.feature.simfunctions.jaro_winkler>,
#  'lev_dist': <function py_entitymatching.feature.simfunctions.lev_dist>,
#  'lev_sim': <function py_entitymatching.feature.simfunctions.lev_sim>,
#  'monge_elkan': <function py_entitymatching.feature.simfunctions.monge_elkan>,
#  'needleman_wunsch': <function py_entitymatching.feature.simfunctions.needleman_wunsch>,
#  'overlap_coeff': <function py_entitymatching.feature.simfunctions.overlap_coeff>,
#  'rel_diff': <function py_entitymatching.feature.simfunctions.rel_diff>,
#  'smith_waterman': <function py_entitymatching.feature.simfunctions.smith_waterman>}

# %%
em._match_t
# Out:
# {'alphabetic': <function py_entitymatching.feature.tokenizers.tok_alphabetic>,
#  'alphanumeric': <function py_entitymatching.feature.tokenizers.tok_alphanumeric>,
#  'dlm_dc0': <function py_entitymatching.feature.tokenizers.tok_delim>,
#  'qgm_2': <function py_entitymatching.feature.tokenizers.tok_qgram>,
#  'qgm_3': <function py_entitymatching.feature.tokenizers.tok_qgram>,
#  'wspace': <function py_entitymatching.feature.tokenizers.tok_wspace>}

# %%
em._match_c['corres']
# Out:
# [('ID', 'ID'),
#  ('Title', 'Title'),
#  ('Episodes', 'Episodes'),
#  ('ProductionHouse', 'ProductionHouse'),
#  ('Genres', 'Genres'),
#  ('Type', 'Type'),
#  ('Year', 'Year'),
#  ('Rating', 'Rating'),
#  ('ProductionHouse_Merged', 'ProductionHouse_Merged'),
#  ('Genres_Merged', 'Genres_Merged')]

# %%
feat_subset = feature_table[4:12]
#feat_subset.append(feature_table[34:40])
feat_subset
# Out:
#                        feature_name left_attribute right_attribute  \
# 4       Title_Title_jac_qgm_3_qgm_3          Title           Title
# 5   Title_Title_cos_dlm_dc0_dlm_dc0          Title           Title
# 6   Title_Title_jac_dlm_dc0_dlm_dc0          Title           Title
# 7                   Title_Title_mel          Title           Title
# 8              Title_Title_lev_dist          Title           Title
# 9               Title_Title_lev_sim          Title           Title
# 10                  Title_Title_nmw          Title           Title
# 11                   Title_Title_sw          Title           Title
#
#    left_attr_tokenizer right_attr_tokenizer       simfunction  \
# 4                qgm_3                qgm_3           jaccard
# 5              dlm_dc0              dlm_dc0            cosine
# 6              dlm_dc0              dlm_dc0           jaccard
# 7                 None                 None       monge_elkan
# 8                 None                 None          lev_dist
# 9                 None                 None           lev_sim
# 10                None                 None  needleman_wunsch
# 11                None                 None    smith_waterman
#
#                                                      function  \
# 4       <function Title_Title_jac_qgm_3_qgm_3 at 0x110609050>
# 5   <function Title_Title_cos_dlm_dc0_dlm_dc0 at 0x110609de8>
# 6   <function Title_Title_jac_dlm_dc0_dlm_dc0 at 0x110609b90>
# 7                   <function Title_Title_mel at 0x110609e60>
# 8              <function Title_Title_lev_dist at 0x110609ed8>
# 9               <function Title_Title_lev_sim at 0x110609d70>
# 10                  <function Title_Title_nmw at 0x10f0cb050>
# 11                   <function Title_Title_sw at 0x10f0cb0c8>
#
#                                                                                         function_source  \
# 4   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 5   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 6   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 7   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 8   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 9   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 10  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 11  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
#
#    is_auto_generated
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True

# %%
feature_vectors_I = em.extract_feature_vecs(I, feature_table=feature_table, attrs_after='gold')
feature_vectors_J = em.extract_feature_vecs(J, feature_table=feature_table, attrs_after='gold')
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:04

# %%
feature_vectors_I
# Out:
#        _id  ltable_ID  rtable_ID  ID_ID_exm  ID_ID_anm  ID_ID_lev_dist  \
# 595  46314       3133       3538          0   0.885529               2
# 152   8721        942       1553          0   0.606568               4
# 543  47896       3035       7862          0   0.386034               4
# 365  28671       1817       6110          0   0.297381               3
# 182  24232        993       5135          0   0.193379               3
# 315  18350       1299       3467          0   0.374676               4
# 588  45626       3111       3834          0   0.811424               3
# 593  46215       3125       2838          0   0.908160               4
# 492  54718       2786       3333          0   0.835884               4
# 9    14939         58       2746          0   0.021122               4
# 37    7389        255       1300          0   0.196154               4
# 55   38061        368       3987          0   0.092300               2
# 428    133       2542         42          0   0.016522               2
# 247  36062       1103       7247          0   0.152201               4
# 252  24273       1109       5136          0   0.215927               3
# 555  49414       3057       1061          0   0.347072               3
# 469  53597       2730       9473          0   0.288187               3
# 308   9768       1238       1745          0   0.709456               3
# 366   6960       1829       1169          0   0.639147               2
# 345    717       1578        128          0   0.081115               2
# 546  48273       3039       2912          0   0.958210               4
# 320  25934       1355       5428          0   0.249632               4
# 442  51817       2674       3638          0   0.735019               3
# 31   11544        225       2085          0   0.107914               2
# 410  16430       2327       3024          0   0.769511               3
# 71   39137        404       1052          0   0.384030               3
# 65   30104        386       6335          0   0.060931               3
# 177   3926        988        704          0   0.712551               3
# 179  15218        991       2788          0   0.355452               4
# 567  43199       3077        995          0   0.323367               4
# ..     ...        ...        ...        ...        ...             ...
# 64   38691        384       8559          0   0.044865               4
# 348   1726       1599        329          0   0.205754               3
# 435  21084       2626       4210          0   0.623753               4
# 157  18899        949       3611          0   0.262808               4
# 85   40100        425        820          0   0.518293               2
# 504  16654       2947       3126          0   0.942738               4
# 335  19700       1481       3782          0   0.391592               3
# 353  27674       1645       5944          0   0.276750               3
# 201   3267       1021        573          0   0.561214               4
# 329  26508       1386       5629          0   0.246225               4
# 88   40362        431       8995          0   0.047916               4
# 517  50521       2985       1234          0   0.413400               4
# 119  36469        704       7294          0   0.096518               2
# 361  35273       1754       7137          0   0.245762               4
# 223  20907       1054       4117          0   0.256012               4
# 390  17339       1961       3265          0   0.600613               3
# 118  11598        626       2087          0   0.299952               4
# 178  16699        989       3131          0   0.315874               4
# 115  22983        569       4813          0   0.118221               4
# 405  16496       2307       3067          0   0.752201               2
# 473  53800       2737       7648          0   0.357871               4
# 585  45485       3107       3576          0   0.868848               3
# 432   7109       2620       1231          0   0.469847               4
# 356  29319       1707       6188          0   0.275856               4
# 341  28067       1517       6005          0   0.252623               4
# 75   39371        411        424          0   0.969340               2
# 385  35918       1954       7232          0   0.270188               4
# 189  30703        999       6441          0   0.155100               4
# 455  17158       2696       3247          0   0.830305               4
# 403  11471       2241       2069          0   0.923249               3
#
#      ID_ID_lev_sim  Title_Title_jac_qgm_3_qgm_3  \
# 595       0.500000                     1.000000
# 152       0.000000                     0.163636
# 543       0.000000                     1.000000
# 365       0.250000                     0.523810
# 182       0.250000                     0.173913
# 315       0.000000                     0.172414
# 588       0.250000                     1.000000
# 593       0.000000                     1.000000
# 492       0.000000                     1.000000
# 9         0.000000                     0.274510
# 37        0.000000                     0.147541
# 55        0.500000                     1.000000
# 428       0.500000                     0.163636
# 247       0.000000                     0.212766
# 252       0.250000                     0.176471
# 555       0.250000                     1.000000
# 469       0.250000                     1.000000
# 308       0.250000                     0.183673
# 366       0.500000                     0.152542
# 345       0.500000                     0.345455
# 546       0.000000                     1.000000
# 320       0.000000                     0.220000
# 442       0.250000                     1.000000
# 31        0.500000                     0.132353
# 410       0.250000                     0.225000
# 71        0.250000                     1.000000
# 65        0.250000                     0.196429
# 177       0.000000                     0.158730
# 179       0.000000                     0.183673
# 567       0.000000                     1.000000
# ..             ...                          ...
# 64        0.000000                     1.000000
# 348       0.250000                     0.108434
# 435       0.000000                     0.256757
# 157       0.000000                     0.256410
# 85        0.333333                     1.000000
# 504       0.000000                     1.000000
# 335       0.250000                     0.140845
# 353       0.250000                     0.527273
# 201       0.000000                     0.183673
# 329       0.000000                     0.169811
# 88        0.000000                     1.000000
# 517       0.000000                     1.000000
# 119       0.500000                     0.075000
# 361       0.000000                     0.157895
# 223       0.000000                     0.264706
# 390       0.250000                     0.157895
# 118       0.000000                     0.149425
# 178       0.000000                     0.263158
# 115       0.000000                     0.321429
# 405       0.500000                     0.176471
# 473       0.000000                     1.000000
# 585       0.250000                     1.000000
# 432       0.000000                     0.063830
# 356       0.000000                     1.000000
# 341       0.000000                     1.000000
# 75        0.333333                     1.000000
# 385       0.000000                     1.000000
# 189       0.000000                     0.255319
# 455       0.000000                     0.151515
# 403       0.250000                     0.123077
#
#      Title_Title_cos_dlm_dc0_dlm_dc0  Title_Title_jac_dlm_dc0_dlm_dc0  ...   \
# 595                         1.000000                         1.000000  ...
# 152                         0.258199                         0.142857  ...
# 543                         1.000000                         1.000000  ...
# 365                         0.566947                         0.375000  ...
# 182                         0.408248                         0.250000  ...
# 315                         0.500000                         0.333333  ...
# 588                         1.000000                         1.000000  ...
# 593                         1.000000                         1.000000  ...
# 492                         1.000000                         1.000000  ...
# 9                           0.000000                         0.000000  ...
# 37                          0.188982                         0.100000  ...
# 55                          1.000000                         1.000000  ...
# 428                         0.250000                         0.142857  ...
# 247                         0.288675                         0.166667  ...
# 252                         0.223607                         0.125000  ...
# 555                         1.000000                         1.000000  ...
# 469                         1.000000                         1.000000  ...
# 308                         0.235702                         0.125000  ...
# 366                         0.288675                         0.166667  ...
# 345                         0.365148                         0.222222  ...
# 546                         1.000000                         1.000000  ...
# 320                         0.447214                         0.285714  ...
# 442                         1.000000                         1.000000  ...
# 31                          0.223607                         0.090909  ...
# 410                         0.353553                         0.200000  ...
# 71                          1.000000                         1.000000  ...
# 65                          0.182574                         0.100000  ...
# 177                         0.223607                         0.125000  ...
# 179                         0.353553                         0.200000  ...
# 567                         1.000000                         1.000000  ...
# ..                               ...                              ...  ...
# 64                          1.000000                         1.000000  ...
# 348                         0.000000                         0.000000  ...
# 435                         0.282843                         0.153846  ...
# 157                         0.516398                         0.333333  ...
# 85                          1.000000                         1.000000  ...
# 504                         1.000000                         1.000000  ...
# 335                         0.166667                         0.090909  ...
# 353                         0.544331                         0.363636  ...
# 201                         0.316228                         0.166667  ...
# 329                         0.000000                         0.000000  ...
# 88                          1.000000                         1.000000  ...
# 517                         1.000000                         1.000000  ...
# 119                         0.000000                         0.000000  ...
# 361                         0.158114                         0.083333  ...
# 223                         0.408248                         0.250000  ...
# 390                         0.000000                         0.000000  ...
# 118                         0.251976                         0.142857  ...
# 178                         0.288675                         0.166667  ...
# 115                         0.338062                         0.200000  ...
# 405                         0.250000                         0.142857  ...
# 473                         1.000000                         1.000000  ...
# 585                         1.000000                         1.000000  ...
# 432                         0.083333                         0.041667  ...
# 356                         1.000000                         1.000000  ...
# 341                         1.000000                         1.000000  ...
# 75                          1.000000                         1.000000  ...
# 385                         1.000000                         1.000000  ...
# 189                         0.500000                         0.333333  ...
# 455                         0.298142                         0.166667  ...
# 403                         0.188982                         0.100000  ...
#
#      ProductionHouse_Merged_ProductionHouse_Merged_jwn  \
# 595                                           0.873684
# 152                                           0.365763
# 543                                           1.000000
# 365                                           0.671397
# 182                                           0.442308
# 315                                           0.436254
# 588                                           0.704741
# 593                                           0.466250
# 492                                           0.660317
# 9                                             0.474854
# 37                                            0.000000
# 55                                                 NaN
# 428                                           0.000000
# 247                                           0.640068
# 252                                           0.444444
# 555                                           0.873684
# 469                                           0.412346
# 308                                           0.447619
# 366                                           0.517949
# 345                                           0.831111
# 546                                                NaN
# 320                                           0.466667
# 442                                           1.000000
# 31                                            0.409722
# 410                                           0.435656
# 71                                            0.256322
# 65                                            0.851852
# 177                                           0.000000
# 179                                           0.536134
# 567                                           0.526786
# ..                                                 ...
# 64                                            0.676314
# 348                                           0.437374
# 435                                           1.000000
# 157                                           0.000000
# 85                                            0.550000
# 504                                           0.821055
# 335                                           0.479167
# 353                                           0.673214
# 201                                           0.554834
# 329                                           0.000000
# 88                                            0.841176
# 517                                           0.516667
# 119                                           0.400673
# 361                                           0.376970
# 223                                           0.450980
# 390                                           0.492816
# 118                                           0.522619
# 178                                                NaN
# 115                                           0.310606
# 405                                           0.555466
# 473                                           0.895000
# 585                                                NaN
# 432                                           0.000000
# 356                                           0.821875
# 341                                           0.838235
# 75                                                 NaN
# 385                                           0.533043
# 189                                           0.450794
# 455                                           0.357123
# 403                                           0.708314
#
#      ProductionHouse_Merged_ProductionHouse_Merged_exm  \
# 595                                                0.0
# 152                                                0.0
# 543                                                1.0
# 365                                                0.0
# 182                                                0.0
# 315                                                0.0
# 588                                                0.0
# 593                                                0.0
# 492                                                0.0
# 9                                                  0.0
# 37                                                 0.0
# 55                                                 NaN
# 428                                                0.0
# 247                                                0.0
# 252                                                0.0
# 555                                                0.0
# 469                                                0.0
# 308                                                0.0
# 366                                                0.0
# 345                                                0.0
# 546                                                NaN
# 320                                                0.0
# 442                                                1.0
# 31                                                 0.0
# 410                                                0.0
# 71                                                 0.0
# 65                                                 0.0
# 177                                                0.0
# 179                                                0.0
# 567                                                0.0
# ..                                                 ...
# 64                                                 0.0
# 348                                                0.0
# 435                                                1.0
# 157                                                0.0
# 85                                                 0.0
# 504                                                0.0
# 335                                                0.0
# 353                                                0.0
# 201                                                0.0
# 329                                                0.0
# 88                                                 0.0
# 517                                                0.0
# 119                                                0.0
# 361                                                0.0
# 223                                                0.0
# 390                                                0.0
# 118                                                0.0
# 178                                                NaN
# 115                                                0.0
# 405                                                0.0
# 473                                                0.0
# 585                                                NaN
# 432                                                0.0
# 356                                                0.0
# 341                                                0.0
# 75                                                 NaN
# 385                                                0.0
# 189                                                0.0
# 455                                                0.0
# 403                                                0.0
#
#      ProductionHouse_Merged_ProductionHouse_Merged_jac_qgm_3_qgm_3  \
# 595                                                       0.304348
# 152                                                       0.000000
# 543                                                       1.000000
# 365                                                       0.217391
# 182                                                       0.000000
# 315                                                       0.000000
# 588                                                       0.400000
# 593                                                       0.018182
# 492                                                       0.320000
# 9                                                         0.000000
# 37                                                        0.000000
# 55                                                             NaN
# 428                                                       0.000000
# 247                                                       0.000000
# 252                                                       0.000000
# 555                                                       0.304348
# 469                                                       0.161290
# 308                                                       0.000000
# 366                                                       0.000000
# 345                                                       0.142857
# 546                                                            NaN
# 320                                                       0.000000
# 442                                                       1.000000
# 31                                                        0.000000
# 410                                                       0.013889
# 71                                                        0.000000
# 65                                                        0.454545
# 177                                                       0.000000
# 179                                                       0.000000
# 567                                                       0.015873
# ..                                                             ...
# 64                                                        0.145833
# 348                                                       0.000000
# 435                                                       1.000000
# 157                                                       0.000000
# 85                                                        0.083333
# 504                                                       0.196078
# 335                                                       0.000000
# 353                                                       0.225806
# 201                                                       0.000000
# 329                                                       0.000000
# 88                                                        0.184211
# 517                                                       0.000000
# 119                                                       0.000000
# 361                                                       0.000000
# 223                                                       0.000000
# 390                                                       0.000000
# 118                                                       0.000000
# 178                                                            NaN
# 115                                                       0.000000
# 405                                                       0.000000
# 473                                                       0.608696
# 585                                                            NaN
# 432                                                       0.000000
# 356                                                       0.107692
# 341                                                       0.206349
# 75                                                             NaN
# 385                                                       0.018519
# 189                                                       0.052632
# 455                                                       0.000000
# 403                                                       0.391304
#
#      Genres_Merged_Genres_Merged_lev_dist  \
# 595                                  14.0
# 152                                   NaN
# 543                                  24.0
# 365                                  46.0
# 182                                  19.0
# 315                                  35.0
# 588                                  40.0
# 593                                  19.0
# 492                                  18.0
# 9                                     6.0
# 37                                   10.0
# 55                                    NaN
# 428                                  22.0
# 247                                   NaN
# 252                                  38.0
# 555                                  23.0
# 469                                  17.0
# 308                                  12.0
# 366                                  20.0
# 345                                  19.0
# 546                                  39.0
# 320                                  37.0
# 442                                   NaN
# 31                                   27.0
# 410                                  14.0
# 71                                   18.0
# 65                                   31.0
# 177                                   NaN
# 179                                  24.0
# 567                                  41.0
# ..                                    ...
# 64                                   43.0
# 348                                  39.0
# 435                                  27.0
# 157                                   NaN
# 85                                   39.0
# 504                                  30.0
# 335                                  35.0
# 353                                  21.0
# 201                                   NaN
# 329                                   NaN
# 88                                   25.0
# 517                                  17.0
# 119                                  29.0
# 361                                   NaN
# 223                                  31.0
# 390                                  34.0
# 118                                  26.0
# 178                                  13.0
# 115                                  13.0
# 405                                  57.0
# 473                                  28.0
# 585                                  45.0
# 432                                   NaN
# 356                                  35.0
# 341                                  39.0
# 75                                   31.0
# 385                                  47.0
# 189                                  15.0
# 455                                  34.0
# 403                                   NaN
#
#      Genres_Merged_Genres_Merged_lev_sim  Genres_Merged_Genres_Merged_jar  \
# 595                             0.263158                         0.621053
# 152                                  NaN                              NaN
# 543                             0.250000                         0.356481
# 365                             0.220339                         0.596238
# 182                             0.424242                         0.672559
# 315                             0.222222                         0.545351
# 588                             0.111111                         0.475661
# 593                             0.321429                         0.504233
# 492                             0.250000                         0.305556
# 9                               0.454545                         0.430303
# 37                              0.090909                         0.430303
# 55                                   NaN                              NaN
# 428                             0.153846                         0.504274
# 247                                  NaN                              NaN
# 252                             0.136364                         0.399062
# 555                             0.178571                         0.523097
# 469                             0.575000                         0.713406
# 308                             0.000000                         0.000000
# 366                             0.310345                         0.602096
# 345                             0.457143                         0.744156
# 546                             0.235294                         0.608543
# 320                             0.159091                         0.470280
# 442                                  NaN                              NaN
# 31                              0.341463                         0.486935
# 410                             0.125000                         0.384722
# 71                              0.437500                         0.761479
# 65                              0.415094                         0.678126
# 177                                  NaN                              NaN
# 179                             0.076923                         0.460684
# 567                             0.305085                         0.594364
# ..                                   ...                              ...
# 64                              0.232143                         0.615842
# 348                             0.133333                         0.585527
# 435                             0.156250                         0.489352
# 157                                  NaN                              NaN
# 85                              0.303571                         0.492063
# 504                             0.333333                         0.580159
# 335                             0.239130                         0.571854
# 353                             0.553191                         0.801093
# 201                                  NaN                              NaN
# 329                                  NaN                              NaN
# 88                              0.285714                         0.551190
# 517                             0.320000                         0.592749
# 119                             0.064516                         0.321505
# 361                                  NaN                              NaN
# 223                             0.138889                         0.589597
# 390                             0.370370                         0.688910
# 118                             0.103448                         0.503429
# 178                             0.315789                         0.716374
# 115                             0.500000                         0.693910
# 405                             0.219178                         0.526969
# 473                             0.125000                         0.525568
# 585                             0.166667                         0.722222
# 432                                  NaN                              NaN
# 356                             0.339623                         0.603994
# 341                             0.417910                         0.717296
# 75                              0.225000                         0.455556
# 385                             0.241935                         0.623127
# 189                             0.210526                         0.385759
# 455                             0.227273                         0.543182
# 403                                  NaN                              NaN
#
#      Genres_Merged_Genres_Merged_jwn  Genres_Merged_Genres_Merged_exm  \
# 595                         0.621053                              0.0
# 152                              NaN                              NaN
# 543                         0.356481                              0.0
# 365                         0.757743                              0.0
# 182                         0.803535                              0.0
# 315                         0.545351                              0.0
# 588                         0.475661                              0.0
# 593                         0.504233                              0.0
# 492                         0.305556                              0.0
# 9                           0.430303                              0.0
# 37                          0.430303                              0.0
# 55                               NaN                              NaN
# 428                         0.504274                              0.0
# 247                              NaN                              NaN
# 252                         0.399062                              0.0
# 555                         0.523097                              0.0
# 469                         0.713406                              0.0
# 308                         0.000000                              0.0
# 366                         0.602096                              0.0
# 345                         0.846494                              0.0
# 546                         0.765126                              0.0
# 320                         0.470280                              0.0
# 442                              NaN                              NaN
# 31                          0.486935                              0.0
# 410                         0.384722                              0.0
# 71                          0.856887                              0.0
# 65                          0.678126                              0.0
# 177                              NaN                              NaN
# 179                         0.460684                              0.0
# 567                         0.756618                              0.0
# ..                               ...                              ...
# 64                          0.615842                              0.0
# 348                         0.585527                              0.0
# 435                         0.489352                              0.0
# 157                              NaN                              NaN
# 85                          0.492063                              0.0
# 504                         0.580159                              0.0
# 335                         0.571854                              0.0
# 353                         0.880656                              0.0
# 201                              NaN                              NaN
# 329                              NaN                              NaN
# 88                          0.551190                              0.0
# 517                         0.592749                              0.0
# 119                         0.321505                              0.0
# 361                              NaN                              NaN
# 223                         0.589597                              0.0
# 390                         0.813346                              0.0
# 118                         0.503429                              0.0
# 178                         0.716374                              0.0
# 115                         0.816346                              0.0
# 405                         0.574272                              0.0
# 473                         0.525568                              0.0
# 585                         0.833333                              0.0
# 432                              NaN                              NaN
# 356                         0.762396                              0.0
# 341                         0.830378                              0.0
# 75                          0.455556                              0.0
# 385                         0.773876                              0.0
# 189                         0.385759                              0.0
# 455                         0.543182                              0.0
# 403                              NaN                              NaN
#
#      Genres_Merged_Genres_Merged_jac_qgm_3_qgm_3  gold
# 595                                     0.037037     1
# 152                                          NaN     0
# 543                                     0.073171     1
# 365                                     0.147059     0
# 182                                     0.196078     0
# 315                                     0.068966     0
# 588                                     0.000000     1
# 593                                     0.093023     1
# 492                                     0.214286     1
# 9                                       0.333333     0
# 37                                      0.052632     0
# 55                                           NaN     1
# 428                                     0.000000     0
# 247                                          NaN     0
# 252                                     0.000000     0
# 555                                     0.046512     1
# 469                                     0.477273     1
# 308                                     0.000000     0
# 366                                     0.219512     0
# 345                                     0.175439     0
# 546                                     0.134328     1
# 320                                     0.057143     0
# 442                                          NaN     1
# 31                                      0.192308     0
# 410                                     0.000000     0
# 71                                      0.261905     1
# 65                                      0.338462     0
# 177                                          NaN     0
# 179                                     0.000000     0
# 567                                     0.181818     1
# ..                                           ...   ...
# 64                                      0.186441     1
# 348                                     0.023256     0
# 435                                     0.000000     1
# 157                                          NaN     0
# 85                                      0.157143     1
# 504                                     0.115942     1
# 335                                     0.131148     0
# 353                                     0.491228     1
# 201                                          NaN     0
# 329                                          NaN     0
# 88                                      0.088889     1
# 517                                     0.116279     1
# 119                                     0.000000     0
# 361                                          NaN     0
# 223                                     0.000000     0
# 390                                     0.105882     0
# 118                                     0.000000     0
# 178                                     0.160000     0
# 115                                     0.277778     0
# 405                                     0.009259     0
# 473                                     0.020408     1
# 585                                     0.175439     1
# 432                                          NaN     0
# 356                                     0.081395     1
# 341                                     0.308642     1
# 75                                      0.098039     1
# 385                                     0.112500     1
# 189                                     0.000000     0
# 455                                     0.081081     0
# 403                                          NaN     0
#
# [300 rows x 44 columns]

# %%
feature_vectors_I.fillna(0, inplace=True)
feature_vectors_J.fillna(0, inplace=True)
feature_vectors_I.head()
feature_vectors_J.head()
# Out:
#        _id  ltable_ID  rtable_ID  ID_ID_exm  ID_ID_anm  ID_ID_lev_dist  \
# 368  18597       1829       3553          0   0.514776               4
# 411   5562       2330        886          0   0.380258               4
# 261   5072       1123        829          0   0.738201               3
# 113  19173        559       3700          0   0.151081               4
# 136  15282        905       2789          0   0.324489               4
#
#      ID_ID_lev_sim  Title_Title_jac_qgm_3_qgm_3  \
# 368           0.00                     0.134146
# 411           0.00                     0.169811
# 261           0.25                     0.230769
# 113           0.00                     0.181818
# 136           0.00                     0.098765
#
#      Title_Title_cos_dlm_dc0_dlm_dc0  Title_Title_jac_dlm_dc0_dlm_dc0  ...   \
# 368                         0.188982                         0.100000  ...
# 411                         0.000000                         0.000000  ...
# 261                         0.316228                         0.166667  ...
# 113                         0.258199                         0.142857  ...
# 136                         0.188982                         0.100000  ...
#
#      ProductionHouse_Merged_ProductionHouse_Merged_jwn  \
# 368                                           0.000000
# 411                                           0.398810
# 261                                           0.000000
# 113                                           0.376068
# 136                                           0.407407
#
#      ProductionHouse_Merged_ProductionHouse_Merged_exm  \
# 368                                                0.0
# 411                                                0.0
# 261                                                0.0
# 113                                                0.0
# 136                                                0.0
#
#      ProductionHouse_Merged_ProductionHouse_Merged_jac_qgm_3_qgm_3  \
# 368                                                            0.0
# 411                                                            0.0
# 261                                                            0.0
# 113                                                            0.0
# 136                                                            0.0
#
#      Genres_Merged_Genres_Merged_lev_dist  \
# 368                                  27.0
# 411                                  22.0
# 261                                   0.0
# 113                                  20.0
# 136                                  39.0
#
#      Genres_Merged_Genres_Merged_lev_sim  Genres_Merged_Genres_Merged_jar  \
# 368                             0.068966                         0.483674
# 411                             0.153846                         0.415618
# 261                             0.000000                         0.000000
# 113                             0.166667                         0.431818
# 136                             0.220000                         0.486708
#
#      Genres_Merged_Genres_Merged_jwn  Genres_Merged_Genres_Merged_exm  \
# 368                         0.483674                              0.0
# 411                         0.415618                              0.0
# 261                         0.000000                              0.0
# 113                         0.431818                              0.0
# 136                         0.486708                              0.0
#
#      Genres_Merged_Genres_Merged_jac_qgm_3_qgm_3  gold
# 368                                     0.000000     0
# 411                                     0.051282     0
# 261                                     0.000000     0
# 113                                     0.000000     0
# 136                                     0.040541     0
#
# [5 rows x 44 columns]

# %%
result = em.select_matcher([dt,rf, svm, nb, lg, ln], table=feature_vectors_I, 
        exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
        target_attr='gold', metric='precision', random_state=0)

# %%
result
# Out:
# OrderedDict([('selected_matcher',
#               <py_entitymatching.matcher.rfmatcher.RFMatcher at 0x10f09d9d0>),
#              ('cv_stats',                  Name  \
#               0        DecisionTree
#               1        RandomForest
#               2                 SVM
#               3          NaiveBayes
#               4  LogisticRegression
#               5    LinearRegression
#
#                                                                                        Matcher  \
#               0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x10f09da10>
#               1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x10f09d9d0>
#               2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x10f09db10>
#               3          <py_entitymatching.matcher.nbmatcher.NBMatcher object at 0x1105f7390>
#               4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x10f09dad0>
#               5  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x10f09d910>
#
#                  Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
#               0          5  0.931034  1.000000  1.000000  1.000000  0.880000    0.962207
#               1          5  1.000000  1.000000  0.956522  0.964286  0.954545    0.975071
#               2          5  1.000000  1.000000  1.000000  0.916667  0.888889    0.961111
#               3          5  0.925926  0.941176  0.956522  0.965517  0.956522    0.949133
#               4          5  1.000000  0.941176  0.954545  0.964286  0.956522    0.963306
#               5          5  1.000000  0.888889  1.000000  0.928571  0.954545    0.954401  )])

# %%
result['cv_stats']
# Out:
#                  Name  \
# 0        DecisionTree
# 1        RandomForest
# 2                 SVM
# 3          NaiveBayes
# 4  LogisticRegression
# 5    LinearRegression
#
#                                                                          Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x10f09da10>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x10f09d9d0>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x10f09db10>
# 3          <py_entitymatching.matcher.nbmatcher.NBMatcher object at 0x1105f7390>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x10f09dad0>
# 5  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x10f09d910>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.931034  1.000000  1.000000  1.000000  0.880000    0.962207
# 1          5  1.000000  1.000000  0.956522  0.964286  0.954545    0.975071
# 2          5  1.000000  1.000000  1.000000  0.916667  0.888889    0.961111
# 3          5  0.925926  0.941176  0.956522  0.965517  0.956522    0.949133
# 4          5  1.000000  0.941176  0.954545  0.964286  0.956522    0.963306
# 5          5  1.000000  0.888889  1.000000  0.928571  0.954545    0.954401

# %%
result['selected_matcher']

# %%
splitIForDebug = em.split_train_test(feature_vectors_I, train_proportion=0.5)

# %%
A = splitIForDebug['train']
B = splitIForDebug['test']

# %%
em.vis_debug_rf(rf, A, B, exclude_attrs=['_id', 'ltable_ID', 'rtable_ID'], target_attr='gold')

# %%
# Since there was a false positive detected we are trying to increase the number of training vectors

# %%
# 1. Train RF using I
# 2. Predict VJ using RF
# 3. Evaluate predictions
rf.fit(table=feature_vectors_I,
       exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
       target_attr='gold')
predicted_values = rf.predict(table=feature_vectors_J, exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = em.eval_matches(predicted_values, 'gold', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (120/120)
# Recall : 97.56% (120/123)
# F1 : 98.77%
# False positives : 0 (out of 120 positive predictions)
# False negatives : 3 (out of 180 negative predictions)

# %%
# 1. Train RF using I
# 2. Predict VJ using RF
# 3. Evaluate predictions
dt.fit(table=feature_vectors_I,
       exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
       target_attr='gold')
predicted_values = dt.predict(table=feature_vectors_J, exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = em.eval_matches(predicted_values, 'gold', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 97.56% (120/123)
# Recall : 97.56% (120/123)
# F1 : 97.56%
# False positives : 3 (out of 123 positive predictions)
# False negatives : 3 (out of 177 negative predictions)

# %%
# 1. Train RF using I
# 2. Predict VJ using RF
# 3. Evaluate predictions
svm.fit(table=feature_vectors_I,
       exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
       target_attr='gold')
predicted_values = svm.predict(table=feature_vectors_J, exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = em.eval_matches(predicted_values, 'gold', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 100.0% (72/72)
# Recall : 58.54% (72/123)
# F1 : 73.85%
# False positives : 0 (out of 72 positive predictions)
# False negatives : 51 (out of 228 negative predictions)

# %%
# 1. Train RF using I
# 2. Predict VJ using RF
# 3. Evaluate predictions
nb.fit(table=feature_vectors_I,
       exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
       target_attr='gold')
predicted_values = nb.predict(table=feature_vectors_J, exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = em.eval_matches(predicted_values, 'gold', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 95.93% (118/123)
# Recall : 95.93% (118/123)
# F1 : 95.93%
# False positives : 5 (out of 123 positive predictions)
# False negatives : 5 (out of 177 negative predictions)

# %%
# 1. Train RF using I
# 2. Predict VJ using RF
# 3. Evaluate predictions
lg.fit(table=feature_vectors_I,
       exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
       target_attr='gold')
predicted_values = lg.predict(table=feature_vectors_J, exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = em.eval_matches(predicted_values, 'gold', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 97.54% (119/122)
# Recall : 96.75% (119/123)
# F1 : 97.14%
# False positives : 3 (out of 122 positive predictions)
# False negatives : 4 (out of 178 negative predictions)

# %%
# 1. Train RF using I
# 2. Predict VJ using RF
# 3. Evaluate predictions
ln.fit(table=feature_vectors_I,
       exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
       target_attr='gold')
predicted_values = ln.predict(table=feature_vectors_J, exclude_attrs=['_id', 'ltable_ID', 'rtable_ID', 'gold'],
              append=True, target_attr='predicted', inplace=False)
eval_result = em.eval_matches(predicted_values, 'gold', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 97.54% (119/122)
# Recall : 96.75% (119/123)
# F1 : 97.14%
# False positives : 3 (out of 122 positive predictions)
# False negatives : 4 (out of 178 negative predictions)
